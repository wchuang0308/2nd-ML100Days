# %% [markdown]
# 作業1: 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. Titanic: Machine learning from diaster. This dataset is used as a Kaggle tutorial for beginners of machine learning. This dataset can be used to learn binary classification and Python/R basics.
#
# 2. Data source: Historical data of Titanic Sinking diaster
#
# 3. type: CSV
#
# 4. Predict what sorts of people were likely to survive and verify the model accuracy of survival passengers

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」): a. 如何讓你的車隊的獲利率提高, 獲利率可定為每小時營業時間的收入 2.目前車隊有十台車, 目前每小時平均營業額為 2500元. 3.假設可以透過調整營業時間及里程單價值 (或是優會方案) 來獲取較大的獲利率. 例如  4000元/每小時
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集): 記錄每一天車隊每一台車, 在那個時間戴客, 戴客距離, 雇客種類, 目的地, 出發地點, 附近競爭對手的單價 (將優惠方案轉成單價調整), 長短程不同的價格策略的影響
#
# 3. 蒐集而來的資料型態為何: 存成 CSV 檔或是資料庫格式以利存取分析
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證): 1. 舉辦一些優惠活動, 記錄這些活動對營收的影響 2. 透過資料分析, 調整不同時段不同里程的里程單價, 營業時間, 使得每日的獲利提高. 3. 評估獲利的改變, 來進行策略改善。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y1):
    """
    Calculate MSE
    Args
        y: real values
        y1: prediction values
    return mse: mean squared error
    """
    mse=sum((y1-y)**2)/len(y)
    print("num=", len(y), "error_square_sum=", sum((y1-y)**2))
    return mse   

def mean_absolute_error(y, y1):
    """
    Calculate MAE
    Args
        y: real values
        y1: prediction values
    return mae: mean absolute error
    """
    mae = sum(abs(y1-y))/len(y)
    print("num=", len(y), "error_sum=", sum(abs(y1-y)))
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# num= 101 error_square_sum= 23458.40164097927
# num= 101 error_sum= 1234.3732085027189
# The Mean squared error is 232.261
# The Mean absolute error is 12.222
